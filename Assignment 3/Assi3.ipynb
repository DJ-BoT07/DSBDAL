# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nba.csv")

df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0
# 7            Gonzaga   2165160.0
# 8         Louisville   1824360.0
# 9     Oklahoma State   3431040.0

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df = df.drop(columns=["Number","College"])

# %%
df
# Out:
#               Name            Team Position   Age Height  Weight     Salary
# 0    Avery Bradley  Boston Celtics       PG  25.0    6-2   180.0  7730337.0
# 1      Jae Crowder  Boston Celtics       SF  25.0    6-6   235.0  6796117.0
# 2     John Holland  Boston Celtics       SG  27.0    6-5   205.0        NaN
# 3      R.J. Hunter  Boston Celtics       SG  22.0    6-5   185.0  1148640.0
# 4    Jonas Jerebko  Boston Celtics       PF  29.0   6-10   231.0  5000000.0
# ..             ...             ...      ...   ...    ...     ...        ...
# 453   Shelvin Mack       Utah Jazz       PG  26.0    6-3   203.0  2433333.0
# 454      Raul Neto       Utah Jazz       PG  24.0    6-1   179.0   900000.0
# 455   Tibor Pleiss       Utah Jazz        C  26.0    7-3   256.0  2900000.0
# 456    Jeff Withey       Utah Jazz        C  26.0    7-0   231.0   947276.0
# 457            NaN             NaN      NaN   NaN    NaN     NaN        NaN
#
# [458 rows x 7 columns]

# %%
df = df.dropna(how="any")

# %%
df.isna().sum()
# Out:
# Name        0
# Team        0
# Position    0
# Age         0
# Height      0
# Weight      0
# Salary      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age      Weight        Salary
# count  446.000000  446.000000  4.460000e+02
# mean    26.919283  221.753363  4.842684e+06
# std      4.398951   26.157899  5.229238e+06
# min     19.000000  161.000000  3.088800e+04
# 25%     24.000000  200.000000  1.044792e+06
# 50%     26.000000  220.000000  2.839073e+06
# 75%     30.000000  240.000000  6.500000e+06
# max     40.000000  307.000000  2.500000e+07

# %%
print(f"Mean is {df['Age'].mean()}")
print(f"Median is {df['Age'].median()}")
print(f"Max is {df['Age'].max()}")
print(f"Min is {df['Age'].min()}")
print(f"Std Deviation is {df['Age'].std()}")
# Out:
# Mean is 26.919282511210763
# Median is 26.0
# Max is 40.0
# Min is 19.0
# Std Deviation is 4.39895139966757

# %%
plt.plot(df['Age'])
plt.axhline(df['Age'].mean(),label='Mean',color='r',linestyle='-')
plt.axhline(df['Age'].median(),label='Median',color='r',linestyle='--')
plt.legend()
plt.xlabel("Value")
plt.ylabel("Stats")
# Out:
# Text(0, 0.5, 'Stats')

# %%
df
# Out:
#               Name            Team Position   Age Height  Weight      Salary
# 0    Avery Bradley  Boston Celtics       PG  25.0    6-2   180.0   7730337.0
# 1      Jae Crowder  Boston Celtics       SF  25.0    6-6   235.0   6796117.0
# 3      R.J. Hunter  Boston Celtics       SG  22.0    6-5   185.0   1148640.0
# 4    Jonas Jerebko  Boston Celtics       PF  29.0   6-10   231.0   5000000.0
# 5     Amir Johnson  Boston Celtics       PF  29.0    6-9   240.0  12000000.0
# ..             ...             ...      ...   ...    ...     ...         ...
# 452     Trey Lyles       Utah Jazz       PF  20.0   6-10   234.0   2239800.0
# 453   Shelvin Mack       Utah Jazz       PG  26.0    6-3   203.0   2433333.0
# 454      Raul Neto       Utah Jazz       PG  24.0    6-1   179.0    900000.0
# 455   Tibor Pleiss       Utah Jazz        C  26.0    7-3   256.0   2900000.0
# 456    Jeff Withey       Utah Jazz        C  26.0    7-0   231.0    947276.0
#
# [446 rows x 7 columns]

# %%
print(f"Mean is {df.Salary.mean()}")
print(f"Median is {df.Salary.median()}")
print(f"Max is {df.Salary.max()}")
print(f"Min is {df.Salary.min()}")
print(f"Std Deviation is {df.Salary.std()}")

plt.plot(df["Salary"])
plt.axhline(y=df["Salary"].mean(),color='r',linestyle='-',label='Mean')
plt.axhline(y=df["Salary"].median(),color='g',linestyle='--',label='Median')
plt.legend()
plt.ylabel("Salary")
plt.title("Stats of Salary")
plt.show()
# Out:
# Mean is 4842684.105381166
# Median is 2839073.0
# Max is 25000000.0
# Min is 30888.0
# Std Deviation is 5229237.598910348

# %%
print(f"Mean is {df.Weight.mean()}")
print(f"Median is {df.Weight.median()}")
print(f"Max is {df.Weight.max()}")
print(f"Min is {df.Weight.min()}")
print(f"Std Deviation is {df.Weight.std()}")

plt.plot(df["Weight"],alpha=0.25)
plt.axhline(y=df["Weight"].mean(),color='r',linestyle='-',label='Mean')
plt.axhline(y=df["Weight"].median(),color='g',linestyle='--',label='Median')
plt.legend()
plt.ylabel("Weight")
plt.title("Stats of Weight")
plt.show()
# Out:
# Mean is 221.75336322869956
# Median is 220.0
# Max is 307.0
# Min is 161.0
# Std Deviation is 26.15789866982012

# %%
df1 = df.groupby(by=['Age'])[['Weight', 'Salary']].mean()

# %%
df1
# Out:
#           Weight        Salary
# Age
# 19.0  204.000000  1.930440e+06
# 20.0  223.736842  2.725791e+06
# 21.0  220.894737  2.067380e+06
# 22.0  224.230769  2.357963e+06
# 23.0  215.410256  2.034746e+06
# 24.0  218.155556  3.785300e+06
# 25.0  213.522727  3.930867e+06
# 26.0  228.500000  6.866566e+06
# 27.0  220.850000  6.676741e+06
# 28.0  221.400000  5.110189e+06
# 29.0  235.296296  6.224177e+06
# 30.0  214.966667  7.061859e+06
# 31.0  229.772727  8.511397e+06
# 32.0  220.846154  7.716958e+06
# 33.0  226.357143  3.930739e+06
# 34.0  227.300000  7.606030e+06
# 35.0  229.750000  3.461740e+06
# 36.0  222.100000  2.238120e+06
# 37.0  234.000000  1.277778e+07
# 38.0  218.750000  1.840041e+06
# 39.0  202.500000  2.517872e+06
# 40.0  230.000000  4.666917e+06

# %%
df1['Weight'].plot()
# Out:
# <Axes: xlabel='Age'>

# %%
df1["Salary"].plot()
# Out:
# <Axes: xlabel='Age'>

# %%
#Part 2

# %%
import  seaborn as sb

# %%
df2 = sb.load_dataset('iris')

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
arr=[]
for item in df2['species']:
    if item not in arr:
        arr.append(item)

print(arr)
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
df = df2

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
gr = df.groupby('species')

# %%
se = gr.get_group('setosa')
ve = gr.get_group('versicolor')
vi = gr.get_group('virginica')

# %%
se.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
ve.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
vi.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
df_grp = df.groupby(by=['species'])[['sepal_length','sepal_width', 'petal_length', 'petal_width']].mean()
df_grp
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
