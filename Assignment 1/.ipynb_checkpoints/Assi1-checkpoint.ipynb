# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG
# 0     40   M           ATA        140          289          0     Normal  \
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0   40   M           ATA        140          289          0     Normal    172  \
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#                Age  Sex ChestPainType   RestingBP  Cholesterol   FastingBS
# count   918.000000  918           918  918.000000   918.000000  918.000000  \
# unique         NaN    2             4         NaN          NaN         NaN
# top            NaN    M           ASY         NaN          NaN         NaN
# freq           NaN  725           496         NaN          NaN         NaN
# mean     53.510893  NaN           NaN  132.396514   198.799564    0.233115
# std       9.432617  NaN           NaN   18.514154   109.384145    0.423046
# min      28.000000  NaN           NaN    0.000000     0.000000    0.000000
# 25%      47.000000  NaN           NaN  120.000000   173.250000    0.000000
# 50%      54.000000  NaN           NaN  130.000000   223.000000    0.000000
# 75%      60.000000  NaN           NaN  140.000000   267.000000    0.000000
# max      77.000000  NaN           NaN  200.000000   603.000000    1.000000
#
#        RestingECG       MaxHR ExerciseAngina     Oldpeak ST_Slope
# ...

# %%
X = df.drop("HeartDisease", axis = 1)
X.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0   40   M           ATA        140          289          0     Normal    172  \
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope
# 0              N      0.0       Up
# 1              N      1.0     Flat
# 2              N      0.0       Up
# 3              Y      1.5     Flat
# 4              N      0.0       Up

# %%
Y = df["HeartDisease"]
Y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64

# %%
plt.scatter(df.Cholesterol, df.HeartDisease,color = "red")
plt.xlabel("Chol")
plt.ylabel("HeartDisease or not")
# Out:
# Text(0, 0.5, 'HeartDisease or not')

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
s=df.drop("Sex",axis=1)
s
# Out:
#      Age ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0     40           ATA        140          289          0     Normal    172  \
# 1     49           NAP        160          180          0     Normal    156
# 2     37           ATA        130          283          0         ST     98
# 3     48           ASY        138          214          0     Normal    108
# 4     54           NAP        150          195          0     Normal    122
# ..   ...           ...        ...          ...        ...        ...    ...
# 913   45            TA        110          264          0     Normal    132
# 914   68           ASY        144          193          1     Normal    141
# 915   57           ASY        130          131          0     Normal    115
# 916   57           ATA        130          236          0        LVH    174
# 917   38           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.drop("ChestPainType",axis=1)
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0     40   M        140          289          0     Normal    172  \
# 1     49   F        160          180          0     Normal    156
# 2     37   M        130          283          0         ST     98
# 3     48   F        138          214          0     Normal    108
# 4     54   M        150          195          0     Normal    122
# ..   ...  ..        ...          ...        ...        ...    ...
# 913   45   M        110          264          0     Normal    132
# 914   68   M        144          193          1     Normal    141
# 915   57   M        130          131          0     Normal    115
# 916   57   F        130          236          0        LVH    174
# 917   38   M        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0                N      0.0       Up             0
# 1                N      1.0     Flat             1
# ...

# %%
X = df.drop(['Sex', 'ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],axis=1)
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
# [918 rows x 7 columns]

# %%
Y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
model = LogisticRegression(max_iter=200)
model.fit(X,Y)
# Out:
# LogisticRegression(max_iter=200)

# %% [markdown]
# model.fit(X,Y)

# %%
y_pred=model.predict(X)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print("Accuracy Score:", accuracy_score(Y,y_pred))
# Out:
# Accuracy Score: 1.0

# %%
conf = confusion_matrix(Y, y_pred)
print("Confusion Matrix:")
print(conf)
# Out:
# Confusion Matrix:
# [[410   0]
#  [  0 508]]

# %%
output=model.predict([[30,120,300,1,150,1.0,1]])
def prediction(p):
    if(p[0]==0):
        print("Patient is not HeartDiseased")
        print(p)
    else:
        print("Patient is HeartDiseased")
        print(p)
# Out:
# C:\Python 3.11\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df["Oldpeak"] = df["Oldpeak"].astype("int64")

# %%
df.dtypes
# Out:
# Age                int64
# Sex               object
# ChestPainType     object
# RestingBP          int64
# Cholesterol        int64
# FastingBS          int64
# RestingECG        object
# MaxHR              int64
# ExerciseAngina    object
# Oldpeak            int64
# ST_Slope          object
# HeartDisease       int64
# dtype: object

# %%
prediction(output)
# Out:
# Patient is HeartDiseased
# [1]

# %%
print("Acuuracy score is: ",accuracy_score(Y,y_pred))
# Out:
# Acuuracy score is:  1.0

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG
# 0     40   M           ATA        140          289          0     Normal  \
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df = pd.get_dummies(df, dtype = 'int')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df
# Out:
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR  Oldpeak
# 0    0.244898       0.70     0.479270          0  0.788732    0.250  \
# 1    0.428571       0.80     0.298507          0  0.676056    0.375
# 2    0.183673       0.65     0.469320          0  0.267606    0.250
# 3    0.408163       0.69     0.354892          0  0.338028    0.375
# 4    0.530612       0.75     0.323383          0  0.436620    0.250
# ..        ...        ...          ...        ...       ...      ...
# 913  0.346939       0.55     0.437811          0  0.507042    0.375
# 914  0.816327       0.72     0.320066          1  0.570423    0.625
# 915  0.591837       0.65     0.217247          0  0.387324    0.375
# 916  0.591837       0.65     0.391376          0  0.802817    0.250
# 917  0.204082       0.69     0.290216          0  0.795775    0.250
#
#      HeartDisease  Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP
# ...

# %%
num_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
num_cols
scaler = MinMaxScaler()

# %%
df[num_cols] = scaler.fit_transform(df[num_cols] )
df
# Out:
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR  Oldpeak
# 0    0.244898       0.70     0.479270          0  0.788732    0.250  \
# 1    0.428571       0.80     0.298507          0  0.676056    0.375
# 2    0.183673       0.65     0.469320          0  0.267606    0.250
# 3    0.408163       0.69     0.354892          0  0.338028    0.375
# 4    0.530612       0.75     0.323383          0  0.436620    0.250
# ..        ...        ...          ...        ...       ...      ...
# 913  0.346939       0.55     0.437811          0  0.507042    0.375
# 914  0.816327       0.72     0.320066          1  0.570423    0.625
# 915  0.591837       0.65     0.217247          0  0.387324    0.375
# 916  0.591837       0.65     0.391376          0  0.802817    0.250
# 917  0.204082       0.69     0.290216          0  0.795775    0.250
#
#      HeartDisease  Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
